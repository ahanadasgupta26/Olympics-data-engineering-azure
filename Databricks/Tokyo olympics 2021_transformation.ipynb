# %%
from pyspark.sql.functions import col
from pyspark.sql.types import IntegerType,BooleanType,StringType,DataType,DoubleType

# %%
spark

# %%
spark.version
# Out:
# '4.1.0'

# %%
type(spark)
# Out:
# pyspark.sql.connect.session.SparkSession

# %%
spark.sql("SHOW EXTERNAL LOCATIONS").show(truncate=False)
# Out:
# +----------------------+----------------------------------------------------------------+-------+
# |name                  |url                                                             |comment|
# +----------------------+----------------------------------------------------------------+-------+
# |tokyo-olympic-location|abfss://tokyo-olympic-data@olympic2021data.dfs.core.windows.net/|NULL   |
# +----------------------+----------------------------------------------------------------+-------+

# %%
display(dbutils.fs.ls("abfss://tokyo-olympic-data@olympic2021data.dfs.core.windows.net/raw-data/"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
athletes=spark.read.csv("abfss://tokyo-olympic-data@olympic2021data.dfs.core.windows.net/raw-data/athletes.csv",header=True,inferSchema=True)

# %%
athletes.show(5)
# Out:
# +-----------------+-------+-------------------+
# |       PersonName|Country|         Discipline|
# +-----------------+-------+-------------------+
# |  AALERUD Katrine| Norway|       Cycling Road|
# |      ABAD Nestor|  Spain|Artistic Gymnastics|
# |ABAGNALE Giovanni|  Italy|             Rowing|
# |   ABALDE Alberto|  Spain|         Basketball|
# |    ABALDE Tamara|  Spain|         Basketball|
# +-----------------+-------+-------------------+
# only showing top 5 rows

# %%
coaches=spark.read.csv("abfss://tokyo-olympic-data@olympic2021data.dfs.core.windows.net/raw-data/coaches.csv",header=True,inferSchema=True)

# %%
coaches.show(5)
# Out:
# +---------------+-------------+----------+-----+
# |           Name|      Country|Discipline|Event|
# +---------------+-------------+----------+-----+
# |ABDELMAGID Wael|        Egypt|  Football| NULL|
# |      ABE Junya|        Japan|Volleyball| NULL|
# |  ABE Katsuhiko|        Japan|Basketball| NULL|
# |   ADAMA Cherif|C�te d'Ivoire|  Football| NULL|
# |     AGEBA Yuya|        Japan|Volleyball| NULL|
# +---------------+-------------+----------+-----+
# only showing top 5 rows

# %%
entriesgender=spark.read.csv("abfss://tokyo-olympic-data@olympic2021data.dfs.core.windows.net/raw-data/entriesGender.csv",header=True,inferSchema=True)

# %%
entriesgender = spark.read.csv("abfss://tokyo-olympic-data@olympic2021data.dfs.core.windows.net/raw-data/entriesGender", header=True, inferSchema=True)

# %%
entriesgender.show(5)
# Out:
# +-------------------+------+----+-----+
# |         Discipline|Female|Male|Total|
# +-------------------+------+----+-----+
# |     3x3 Basketball|    32|  32|   64|
# |            Archery|    64|  64|  128|
# |Artistic Gymnastics|    98|  98|  196|
# |  Artistic Swimming|   105|   0|  105|
# |          Athletics|   969|1072| 2041|
# +-------------------+------+----+-----+
# only showing top 5 rows

# %%
medals = spark.read.csv("abfss://tokyo-olympic-data@olympic2021data.dfs.core.windows.net/raw-data/medals.csv", header=True, inferSchema=True)

# %%
medals.show(5)
# Out:
# +----+--------------------+----+------+------+-----+-------------+
# |Rank|         TeamCountry|Gold|Silver|Bronze|Total|Rank by Total|
# +----+--------------------+----+------+------+-----+-------------+
# |   1|United States of ...|  39|    41|    33|  113|            1|
# |   2|People's Republic...|  38|    32|    18|   88|            2|
# |   3|               Japan|  27|    14|    17|   58|            5|
# |   4|       Great Britain|  22|    21|    22|   65|            4|
# |   5|                 ROC|  20|    28|    23|   71|            3|
# +----+--------------------+----+------+------+-----+-------------+
# only showing top 5 rows

# %%
teams= spark.read.csv("abfss://tokyo-olympic-data@olympic2021data.dfs.core.windows.net/raw-data/teams.csv", header=True, inferSchema=True)

# %%
teams.show(5)
# Out:
# +--------+--------------+--------------------+-----+
# |TeamName|    Discipline|             Country|Event|
# +--------+--------------+--------------------+-----+
# | Belgium|3x3 Basketball|             Belgium|  Men|
# |   China|3x3 Basketball|People's Republic...|  Men|
# |   China|3x3 Basketball|People's Republic...|Women|
# |  France|3x3 Basketball|              France|Women|
# |   Italy|3x3 Basketball|               Italy|Women|
# +--------+--------------+--------------------+-----+
# only showing top 5 rows

# %%
athletes.printSchema()
coaches.printSchema()
entriesgender.printSchema()
medals.printSchema()
teams.printSchema()
# Out:
# root
#  |-- PersonName: string (nullable = true)
#  |-- Country: string (nullable = true)
#  |-- Discipline: string (nullable = true)
#
# root
#  |-- Name: string (nullable = true)
#  |-- Country: string (nullable = true)
#  |-- Discipline: string (nullable = true)
#  |-- Event: string (nullable = true)
#
# root
#  |-- Discipline: string (nullable = true)
#  |-- Female: integer (nullable = true)
#  |-- Male: integer (nullable = true)
#  |-- Total: integer (nullable = true)
#
# root
#  |-- Rank: integer (nullable = true)
#  |-- TeamCountry: string (nullable = true)
#  |-- Gold: integer (nullable = true)
#  |-- Silver: integer (nullable = true)
#  |-- Bronze: integer (nullable = true)
#  |-- Total: integer (nullable = true)
#  |-- Rank by Total: integer (nullable = true)
#
# root
#  |-- TeamName: string (nullable = true)
#  |-- Discipline: string (nullable = true)
#  |-- Country: string (nullable = true)
#  |-- Event: string (nullable = true)

# %%
top_gold_medals_countries=medals.orderBy("Gold",ascending=False).show()
# Out:
# +----+--------------------+----+------+------+-----+-------------+
# |Rank|         TeamCountry|Gold|Silver|Bronze|Total|Rank by Total|
# +----+--------------------+----+------+------+-----+-------------+
# |   1|United States of ...|  39|    41|    33|  113|            1|
# |   2|People's Republic...|  38|    32|    18|   88|            2|
# |   3|               Japan|  27|    14|    17|   58|            5|
# |   4|       Great Britain|  22|    21|    22|   65|            4|
# |   5|                 ROC|  20|    28|    23|   71|            3|
# |   6|           Australia|  17|     7|    22|   46|            6|
# |   7|         Netherlands|  10|    12|    14|   36|            9|
# |   8|              France|  10|    12|    11|   33|           10|
# |   9|             Germany|  10|    11|    16|   37|            8|
# |  10|               Italy|  10|    10|    20|   40|            7|
# |  14|                Cuba|   7|     3|     5|   15|           18|
# ...

# %%
average_entries_by_gender=entriesgender.withColumn("average_feamale",entriesgender["Female"]/entriesgender["Total"]
).withColumn("average_male",entriesgender["Male"]/entriesgender["Total"]).show()
# Out:
# +--------------------+------+----+-----+-------------------+-------------------+
# |          Discipline|Female|Male|Total|    average_feamale|       average_male|
# +--------------------+------+----+-----+-------------------+-------------------+
# |      3x3 Basketball|    32|  32|   64|                0.5|                0.5|
# |             Archery|    64|  64|  128|                0.5|                0.5|
# | Artistic Gymnastics|    98|  98|  196|                0.5|                0.5|
# |   Artistic Swimming|   105|   0|  105|                1.0|                0.0|
# |           Athletics|   969|1072| 2041| 0.4747672709456149| 0.5252327290543851|
# |           Badminton|    86|  87|  173|0.49710982658959535| 0.5028901734104047|
# |   Baseball/Softball|    90| 144|  234|0.38461538461538464| 0.6153846153846154|
# |          Basketball|   144| 144|  288|                0.5|                0.5|
# |    Beach Volleyball|    48|  48|   96|                0.5|                0.5|
# ...

# %%
athletes.write.mode("overwrite").option("header",True).csv("abfss://tokyo-olympic-data@olympic2021data.dfs.core.windows.net/transformed-data/athletes")

# %%
coaches.write.mode("overwrite").option("header",True).csv("abfss://tokyo-olympic-data@olympic2021data.dfs.core.windows.net/transformed-data/coaches")

# %%
entriesgender.write.mode("overwrite").option("header",True).csv("abfss://tokyo-olympic-data@olympic2021data.dfs.core.windows.net/transformed-data/entriesgender")

# %%
medals.write.mode("overwrite").option("header",True).csv("abfss://tokyo-olympic-data@olympic2021data.dfs.core.windows.net/transformed-data/medals")

# %%
teams.write.mode("overwrite").option("header",True).csv("abfss://tokyo-olympic-data@olympic2021data.dfs.core.windows.net/transformed-data/teams")
